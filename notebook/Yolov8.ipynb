# %%
from ultralytics import YOLO

from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Train the model
train_results = model.train(
    data="/content/drive/MyDrive/dataset/data.yaml",  # path to dataset YAML
    epochs=100,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Evaluate model performance on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/drive/MyDrive/dataset/valid/labels.cache... 88 images, 5 backgrounds, 0 corrupt: 100%|██████████| 88/88 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:03<00:00,  1.73it/s]
#                    all         88        117       0.38      0.428      0.349      0.162
#                  angle         10         12      0.418      0.583      0.403      0.106
#               fracture         39         59      0.313      0.424      0.319      0.131
#                   line         26         35      0.147      0.371      0.211     0.0939
#        messed_up_angle         11         11      0.644      0.333      0.462      0.318
# Speed: 0.7ms preprocess, 18.5ms inference, 0.0ms loss, 3.6ms postprocess per image
# ...

# %%
# Perform object detection on an image
results = model("/content/drive/MyDrive/dataset/test/images/72_jpg.rf.60268e8fdd7719031d78a73b5dcdd38f.jpg")
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/dataset/test/images/72_jpg.rf.60268e8fdd7719031d78a73b5dcdd38f.jpg: 640x512 1 fracture, 72.4ms
# Speed: 3.5ms preprocess, 72.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# <PIL.Image.Image image mode=RGB size=357x450>

# %%
model.train(
    data='/content/drive/MyDrive/dataset/data.yaml',
    epochs=100,
    imgsz=640,
    lr0=0.001  # Lower learning rate for gradual updates
)
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Evaluate model performance on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/drive/MyDrive/dataset/valid/labels.cache... 88 images, 5 backgrounds, 0 corrupt: 100%|██████████| 88/88 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:04<00:00,  1.22it/s]
#                    all         88        117      0.573      0.365      0.369      0.168
#                  angle         10         12      0.489      0.167      0.202     0.0801
#               fracture         39         59       0.64      0.391      0.418      0.155
#                   line         26         35       0.48      0.314      0.226     0.0818
#        messed_up_angle         11         11      0.682      0.588      0.632      0.355
# Speed: 0.6ms preprocess, 9.4ms inference, 0.0ms loss, 10.0ms postprocess per image
# ...

# %%
# Perform object detection on an image
results = model("/content/drive/MyDrive/dataset/test/images/44_jpg.rf.a8f296b8d749e394876fb6979c16caee.jpg")
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/dataset/test/images/44_jpg.rf.a8f296b8d749e394876fb6979c16caee.jpg: 640x416 1 messed_up_angle, 57.8ms
# Speed: 2.8ms preprocess, 57.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 416)
# <PIL.Image.Image image mode=RGB size=920x1500>

# %%
# Export the model to ONNX format
path = model.export(format="onnx")
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
#
# PyTorch: starting from 'runs/detect/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 289.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.8/141.8 kB 323.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.5/291.5 MB 219.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 231.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 307.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 36.1s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime-gpu']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ...
